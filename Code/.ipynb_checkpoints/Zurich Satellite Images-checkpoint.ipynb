# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from skimage.feature import greycomatrix, greycoprops
from skimage import color
from skimage import io
from skimage import exposure
from PIL import Image

# %%
path = os.getcwd()

im_dir = r''+ path + '/../Zurich_dataset/images_tif/'
gt_dir = r''+ path + '/../Zurich_dataset/groundtruth/'

im_names = sorted(os.listdir(im_dir))
gt_names = sorted(os.listdir(gt_dir))
print("images: %i " % len(im_names))
print("ground truth images: %i " % len(gt_names))
# Out:
# images: 20
# ground truth images: 20

# %%
def imgs_stretch_eq(imgs):
    imgs_stretch, imgs_eq = [], []
    for im in imgs:
        # Contrast stretching
        p2, p98 = np.percentile(im, (2, 98))
        img_stretch = exposure.rescale_intensity(im, in_range=(p2, p98))

        # Equalization
        img_eq = exposure.equalize_hist(img_stretch)
        
        # append images
        imgs_stretch.append(img_stretch)
        imgs_eq.append(img_eq)
    return imgs_stretch, imgs_eq


def im_load(path, equalize = False):
    image = np.asarray(io.imread(path))
    if equalize:
        image, _ = imgs_stretch_eq(image)
    return np.asarray(image)


def concatenate_images(img, gt_img):
    'concatenate an image and its ground truth'
    nChannels = len(gt_img.shape)
    w = gt_img.shape[0]
    h = gt_img.shape[1]
    if nChannels == 3:
        cimg = np.concatenate((img, gt_img), axis=1)
    else:
        gt_img_3c = np.zeros((w, h, 3), dtype=np.uint8)
        gt_img8 = img_float_to_uint8(gt_img)          
        gt_img_3c[:,:,0] = gt_img8
        gt_img_3c[:,:,1] = gt_img8
        gt_img_3c[:,:,2] = gt_img8
        img8 = img_float_to_uint8(img)
        cimg = np.concatenate((img8, gt_img_3c), axis=1)
    return cimg

# %%
images = [im_load(im_dir + im_name, equalize = True) for im_name in im_names]
gt = [im_load(gt_dir + gt_name) for gt_name in gt_names]

# %%
images[0]
# Out:
# array([[[ 0.35978739,  0.55516862,  0.19996334,  0.53940616],
#         [ 0.35117302,  0.54857038,  0.19648094,  0.52914223],
#         [ 0.31983138,  0.52914223,  0.18731672,  0.49120235],
#         ...,
#         [ 0.45289589,  0.74211877,  0.65835777,  0.85575513],
#         [ 0.4138563 ,  0.71609238,  0.5672654 ,  0.83357771],
#         [ 0.12554985,  0.43475073,  0.29068915,  0.65835777]],
#
#        [[ 0.36620235,  0.5590176 ,  0.21279326,  0.5590176 ],
#         [ 0.36620235,  0.56414956,  0.21682551,  0.5590176 ],
#         [ 0.33046188,  0.5377566 ,  0.19739736,  0.50733138],
#         ...,
#         [ 0.47324047,  0.76228006,  0.69923021,  0.87701613],
#         [ 0.43914956,  0.72598974,  0.59420821,  0.85447214],
#         [ 0.11638563,  0.38013196,  0.25733138,  0.60227273]],
#
#        [[ 0.3608871 ,  0.55975073,  0.22928886,  0.56304985],
#         [ 0.34824047,  0.55736804,  0.22177419,  0.54673754],
#         [ 0.32954545,  0.54673754,  0.20821114,  0.50678152],
#         ...,
#         [ 0.72085777,  0.8619868 ,  0.81286657,  1.        ],
#         [ 0.50054985,  0.7641129 ,  0.64827713,  0.90945748],
#         [ 0.13031525,  0.38104839,  0.25164956,  0.64167889]],
#
#        ...,
#        [[ 0.25      ,  0.43108504,  0.14882698,  0.34475806],
#         [ 0.26686217,  0.44648094,  0.15744135,  0.36730205],
#         [ 0.26686217,  0.43108504,  0.15194282,  0.34475806],
#         ...,
#         [ 0.06469941,  0.06744868,  0.02052786,  0.06030059],
#         [ 0.04820381,  0.05040323,  0.02052786,  0.09934018],
#         [ 0.05461877,  0.07019795,  0.02052786,  0.27181085]],
#
#        [[ 0.24101906,  0.42778592,  0.1497434 ,  0.36326979],
#         [ 0.25714809,  0.43383431,  0.15524194,  0.3773827 ],
#         [ 0.26942815,  0.43823314,  0.15890762,  0.38764663],
#         ...,
#         [ 0.05993402,  0.06158358,  0.02089443,  0.06524927],
#         [ 0.05480205,  0.05920088,  0.02089443,  0.15524194],
#         [ 0.06378299,  0.08577713,  0.02089443,  0.3513563 ]],
#
#        [[ 0.22727273,  0.4316349 ,  0.15102639,  0.39186217],
#         [ 0.23643695,  0.4210044 ,  0.15102639,  0.38141496],
#         [ 0.24908358,  0.4210044 ,  0.15249267,  0.38874633],
#         ...,
#         [ 0.05865103,  0.0625    ,  0.02052786,  0.0731305 ],
#         [ 0.06323314,  0.0731305 ,  0.02052786,  0.20197947],
#         [ 0.06928152,  0.08577713,  0.02052786,  0.33431085]]])

# %%
#print('Image size = ' + str(imgs[0].shape[0]) + ',' + str(imgs[0].shape[1]))

# Show first image and its groundtruth image
#cimg = concatenate_images(images[0], gt[0])
#fig1 = plt.figure(figsize=(10, 10))
plt.imshow(images[0][:,:,0:3], cmap='Greys_r')

# %%
print(np.max(image, axis = 1))

# %%
print("Images shape: " + str(np.shape(images)))
print("Gt shape: " + str(np.shape(gt)))
# Out:
# Images shape: (20,)
# Gt shape: (20,)
